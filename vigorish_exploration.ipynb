# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/epl_odds_2020.csv')

# %%
vigs = np.zeros(len(df))
for i, row in df.iterrows():
    vigs[i] = 1/row['AvgH'] + 1/row['AvgA'] + 1/row['AvgD'] - 1

# %%
plt.plot(vigs)
